# %% [markdown]
# <a href="https://colab.research.google.com/github/cristinaegus/Pandas_Python_IA/blob/main/An%C3%A1lisis_preliminar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importamos las librerias necesarias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Leemos y cargamos los datos

# %%
df2 = pd.read_csv("/content/sample_data/Ejemplo_Análisis_preliminar.csv",sep=";",encoding='latin-1')

# %%
df2
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0     01/01/1997               7.0                4.0               2.0
# 1     02/01/1997               7.0                3.0               0.0
# 2     03/01/1997               5.0                3.0               2.0
# 3     04/01/1997               7.0                3.0              -1.0
# 4     05/01/1997               2.0                0.0              -1.0
# ...          ...               ...                ...               ...
# 6807  27/12/2015              14.0                7.0              -1.0
# 6808  28/12/2015              15.0                8.0               2.0
# 6809  29/12/2015              11.0                8.0               5.0
# 6810  30/12/2015               9.0                8.0               6.0
# 6811  31/12/2015              12.0               10.0               7.0
#
#       Max Humidity   Mean Humidity   Min Humidity   Max Sea Level PressurehPa  \
# 0            100.0            95.0           76.0                        1010
# 1            100.0            92.0           71.0                        1007
# 2            100.0            85.0           70.0                        1005
# 3             86.0            63.0           49.0                        1012
# 4            100.0            95.0           86.0                        1012
# ...            ...             ...            ...                         ...
# 6807         100.0            77.0           30.0                        1035
# 6808         100.0            78.0           34.0                        1031
# 6809         100.0            89.0           66.0                        1034
# 6810          93.0            87.0           70.0                        1034
# 6811           NaN            90.0           70.0                        1027
#
#        Mean Sea Level PressurehPa   Min Sea Level PressurehPa  \
# 0                            1008                        1004
# 1                            1003                         997
# 2                             999                         996
# 3                            1010                        1005
# 4                            1008                        1005
# ...                           ...                         ...
# 6807                         1030                        1027
# 6808                         1027                        1023
# 6809                         1030                        1026
# 6810                         1029                        1025
# 6811                         1025                        1024
#
#        Max Wind SpeedKm/h   Mean Wind SpeedKm/h  Precipitationmm     Events  \
# 0                      13                     6             0.00        NaN
# 1                      26                     8             0.00       Rain
# 2                      27                    19             0.00  Rain-Snow
# 3                      27                    19             0.00        NaN
# 4                      14                     6             0.00       Snow
# ...                   ...                   ...              ...        ...
# 6807                   14                     6             0.00        Fog
# 6808                   27                     8             0.51       Rain
# 6809                   14                     8             2.03   Fog-Rain
# 6810                   14                     5             0.00        NaN
# 6811                   14                     6             0.25       Rain
#
#       WindDirDegrees
# 0                229
# 1                143
# 2                256
# 3                284
# 4                  2
# ...              ...
# 6807              38
# 6808             243
# 6809             190
# 6810             256
# 6811             313
#
# [6812 rows x 15 columns]

# %% [markdown]
# # Análisis de los datos

# %% [markdown]
# ## Tipado de las variables

# %%
# Conocemos las clases de las variables del dataset usando dtypes
df2.dtypes
# Out:
# CET                             object
# Max TemperatureC               float64
# Mean TemperatureC              float64
# Min TemperatureC               float64
# Max Humidity                   float64
#  Mean Humidity                 float64
#  Min Humidity                  float64
#  Max Sea Level PressurehPa       int64
#  Mean Sea Level PressurehPa      int64
#  Min Sea Level PressurehPa       int64
#  Max Wind SpeedKm/h              int64
#  Mean Wind SpeedKm/h             int64
# Precipitationmm                float64
#  Events                         object
# WindDirDegrees                   int64
# dtype: object

# %% [markdown]
# ## Resumen estadístico de los datos

# %%
# Realizamos un pequeño resumen estadistico de los datos para conocerlos mejor
descripcion = df2.describe()
df2.describe().T
# Out:
#                               count         mean         std    min     25%  \
# Max TemperatureC             6808.0    21.039806    8.867785    0.0    13.0
# Mean TemperatureC            6806.0    14.657949    7.579699   -3.0     8.0
# Min TemperatureC             6808.0     8.642186    6.837860  -10.0     3.0
# Max Humidity                 6808.0    81.134841   17.532334   16.0    68.0
#  Mean Humidity               6806.0    57.968116   19.676689   15.0    41.0
#  Min Humidity                6807.0    34.730571   19.323612    4.0    19.0
#  Max Sea Level PressurehPa   6812.0  1020.529360    6.235941  994.0  1017.0
#  Mean Sea Level PressurehPa  6812.0  1017.973136    6.480085  986.0  1014.0
#  Min Sea Level PressurehPa   6812.0  1015.217410    6.944745  965.0  1011.0
#  Max Wind SpeedKm/h          6812.0    21.953171    9.903914    0.0    14.0
#  Mean Wind SpeedKm/h         6812.0     9.170728    5.110013    0.0     6.0
# Precipitationmm              6812.0     0.111182    0.967174    0.0     0.0
# WindDirDegrees               6812.0   197.234586  119.872777   -1.0    66.0
#
#                                 50%     75%     max
# Max TemperatureC               20.0    29.0    41.0
# Mean TemperatureC              14.0    21.0    32.0
# Min TemperatureC                9.0    14.0    28.0
# Max Humidity                   87.0    94.0   100.0
#  Mean Humidity                 59.0    74.0   100.0
#  Min Humidity                  32.0    48.0   100.0
#  Max Sea Level PressurehPa   1020.0  1024.0  1047.0
#  Mean Sea Level PressurehPa  1018.0  1022.0  1043.0
#  Min Sea Level PressurehPa   1015.0  1019.0  1041.0
#  Max Wind SpeedKm/h            21.0    27.0   182.0
#  Mean Wind SpeedKm/h            8.0    11.0    39.0
# Precipitationmm                 0.0     0.0    32.0
# WindDirDegrees                223.0   299.0   360.0

# %%
descripcion.columns
# Out:
# Index(['Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC',
#        'Max Humidity', ' Mean Humidity', ' Min Humidity',
#        ' Max Sea Level PressurehPa', ' Mean Sea Level PressurehPa',
#        ' Min Sea Level PressurehPa', ' Max Wind SpeedKm/h',
#        ' Mean Wind SpeedKm/h', 'Precipitationmm', 'WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# ### Variable por variable

# %%
# Si quisieramos analizar una variable en concreto
df2['Max TemperatureC'].describe()
# Out:
# count    6808.000000
# mean       21.039806
# std         8.867785
# min         0.000000
# 25%        13.000000
# 50%        20.000000
# 75%        29.000000
# max        41.000000
# Name: Max TemperatureC, dtype: float64

# %%
df2.iloc[:,1].describe()
# Out:
# count    6808.000000
# mean       21.039806
# std         8.867785
# min         0.000000
# 25%        13.000000
# 50%        20.000000
# 75%        29.000000
# max        41.000000
# Name: Max TemperatureC, dtype: float64

# %% [markdown]
# # Transformación de los datos

# %% [markdown]
# ## Corrección de los nombres de las variables

# %% [markdown]
# Los nombres de algunas de las variables tiene un espacio intercalado, convendria eliminarlo para evitar problemas a la hora de llamar a estas columnas

# %%
df2.columns
# Out:
# Index(['CET', 'Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC',
#        'Max Humidity', ' Mean Humidity', ' Min Humidity',
#        ' Max Sea Level PressurehPa', ' Mean Sea Level PressurehPa',
#        ' Min Sea Level PressurehPa', ' Max Wind SpeedKm/h',
#        ' Mean Wind SpeedKm/h', 'Precipitationmm', ' Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.replace(' ','')

# %%
df2.columns
# Out:
# Index(['CET', 'MaxTemperatureC', 'MeanTemperatureC', 'MinTemperatureC',
#        'MaxHumidity', 'MeanHumidity', 'MinHumidity', 'MaxSeaLevelPressurehPa',
#        'MeanSeaLevelPressurehPa', 'MinSeaLevelPressurehPa', 'MaxWindSpeedKm/h',
#        'MeanWindSpeedKm/h', 'Precipitationmm', 'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df2.MaxTemperatureC
# Out:
# 0        7.0
# 1        7.0
# 2        5.0
# 3        7.0
# 4        2.0
#         ...
# 6807    14.0
# 6808    15.0
# 6809    11.0
# 6810     9.0
# 6811    12.0
# Name: MaxTemperatureC, Length: 6812, dtype: float64

# %%
df2["MaxTemperatureC"]
# Out:
# 0        7.0
# 1        7.0
# 2        5.0
# 3        7.0
# 4        2.0
#         ...
# 6807    14.0
# 6808    15.0
# 6809    11.0
# 6810     9.0
# 6811    12.0
# Name: MaxTemperatureC, Length: 6812, dtype: float64

# %% [markdown]
# ## Columna categórica "Eventos"

# %% [markdown]
# Si analizamos la variable Events, podemos ver que tenemos valores NAN.
#
# No son valores perdidos, en este caso siginifica que ese da no hubo ningún evento climatológico. Por lo tanto, cambiamos el `nan` por "No_evento"

# %%
df2['Events'].unique()
# Out:
# array([nan, 'Rain', 'Rain-Snow', 'Snow', 'Fog', 'Fog-Rain',
#        'Rain-Thunderstorm', 'Thunderstorm', 'Rain-Hail-Thunderstorm',
#        'Fog-Thunderstorm', 'Tornado', 'Fog-Rain-Thunderstorm',
#        'Fog-Rain-Snow', 'Fog-Snow', 'Rain-Snow-Thunderstorm', 'Rain-Hail'],
#       dtype=object)

# %%
df2['Events'] = df2['Events'].fillna('No_Evento')
df2['Events'].unique()
# Out:
# array(['No_Evento', 'Rain', 'Rain-Snow', 'Snow', 'Fog', 'Fog-Rain',
#        'Rain-Thunderstorm', 'Thunderstorm', 'Rain-Hail-Thunderstorm',
#        'Fog-Thunderstorm', 'Tornado', 'Fog-Rain-Thunderstorm',
#        'Fog-Rain-Snow', 'Fog-Snow', 'Rain-Snow-Thunderstorm', 'Rain-Hail'],
#       dtype=object)

# %% [markdown]
# ## Conversión de Date a tipo `DateTime`

# %% [markdown]
# Otro error que se puede observar es que la fecha la toma como object
#
# Debemos convertirla a tipo fecha

# %%
df2['CET']
# Out:
# 0       01/01/1997
# 1       02/01/1997
# 2       03/01/1997
# 3       04/01/1997
# 4       05/01/1997
#            ...
# 6807    27/12/2015
# 6808    28/12/2015
# 6809    29/12/2015
# 6810    30/12/2015
# 6811    31/12/2015
# Name: CET, Length: 6812, dtype: object

# %%
# df2['CET1'] = pd.to_datetime(df2['CET'])
df2['CET'] = pd.to_datetime(df2['CET'], format='%d/%m/%Y')

# %%
df2['CET']
# Out:
# 0      1997-01-01
# 1      1997-01-02
# 2      1997-01-03
# 3      1997-01-04
# 4      1997-01-05
#           ...
# 6807   2015-12-27
# 6808   2015-12-28
# 6809   2015-12-29
# 6810   2015-12-30
# 6811   2015-12-31
# Name: CET, Length: 6812, dtype: datetime64[ns]

# %%
df2.dtypes
# Out:
# CET                        datetime64[ns]
# MaxTemperatureC                   float64
# MeanTemperatureC                  float64
# MinTemperatureC                   float64
# MaxHumidity                       float64
# MeanHumidity                      float64
# MinHumidity                       float64
# MaxSeaLevelPressurehPa              int64
# MeanSeaLevelPressurehPa             int64
# MinSeaLevelPressurehPa              int64
# MaxWindSpeedKm/h                    int64
# MeanWindSpeedKm/h                   int64
# Precipitationmm                   float64
# Events                             object
# WindDirDegrees                      int64
# dtype: object

# %% [markdown]
# # Análisis gráfico

# %% [markdown]
# Análisis preliminar de los datos mediante GRÁFICOS
#
# Podemos obtener alguna información relevante o no.
# Esto sirve para tener una primera idea de las variables.

# %% [markdown]
# ## Boxplot

# %%
df2['MinTemperatureC'].plot(kind='box');

# %%
df2['MinTemperatureC'].describe()
# Out:
# count    6808.000000
# mean        8.642186
# std         6.837860
# min       -10.000000
# 25%         3.000000
# 50%         9.000000
# 75%        14.000000
# max        28.000000
# Name: MinTemperatureC, dtype: float64

# %% [markdown]
# ## Boxplot por categorías

# %% [markdown]
# Con los diagramas Boxplot podemos observar cómo difieren los valores de una variable numérica en función de las distintas categorías de otra categórica.
#
# Por ejemplo: Temperatura max en función de los eventos

# %%
import seaborn as sns
# sns.boxplot(x=df2['Events'], y=df2['MaxTemperatureC']);
# Giramos las categorías del eje y para que se lean
sns.boxplot(x=df2['MaxTemperatureC'], y=df2['Events'], orient="y");

# %% [markdown]
# ## Relación entre variables numéricas

# %% [markdown]
# Mediante un gráfico de dispersión observamos cada registro como un punto en un plano de dos dimensiones usando como coordenadas los valores de ese registro en cada una de las características.

# %%
df2.plot(x='MaxTemperatureC', y='MeanTemperatureC', kind='scatter');

# %%
import matplotlib.pyplot as plt
plt.plot(df2['MaxTemperatureC'], df2['MinTemperatureC'],'sg');

# %% [markdown]
# Si sólo coloco una variable, la otra será el índice.
#
# Modificando la almohadilla podemos seleccionar distintas marcas y sus colores

# %%
# Distribución
# plt.plot(df2['MaxTemperatureC'],'.')
# plt.plot(df2['MaxTemperatureC'],'-')
# plt.plot(df2['MaxTemperatureC'],'*')
# plt.plot(df2['MaxTemperatureC'],'m')
# plt.plot(df2['MaxTemperatureC'],'x')
plt.plot(df2.loc[:365,'MaxTemperatureC'],'xm')
# plt.plot(df2['MaxTemperatureC'],'xr')
# plt.plot(df2['MaxTemperatureC'],'^g')
plt.show()

# %%
df2.set_index('CET', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-fceded71a1c1> in <cell line: 1>()
# ----> 1 df2.set_index('CET', inplace=True)
#       2 plt.plot(df2.iloc[:,1],'xr')
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['CET'] are in the columns"

# %%
plt.plot(df2.iloc[:365,1],'xr')
plt.show()

# %% [markdown]
# ## Histogramas

# %% [markdown]
# Un histograma es una representación gráfica de la distribución de un conjunto de datos. Se utiliza para visualizar la **frecuencia con la que aparecen diferentes valores o rangos de valores en un conjunto de datos**.
#
# Características principales de un histograma:
#
# 1. El eje horizontal (eje x) representa los valores o rangos de valores de los datos, generalmente divididos en intervalos o "bins".
#
# 2. El eje vertical (eje y) representa la frecuencia o el conteo de los valores que caen dentro de cada intervalo.
#
# 3. Los datos se agrupan en barras verticales, donde la altura de cada barra representa la frecuencia de los valores dentro de ese intervalo.
#
#
# Los histogramas son útiles para:
#
# 1. Visualizar la distribución de los datos y detectar patrones.
#
# 2. Identificar la forma de la distribución (simétrica, sesgada, bimodal, etc.).
#
# 3. Determinar el rango y la dispersión de los datos.
#
# 4. Comparar distribuciones de diferentes conjuntos de datos.

# %%
df2.hist(column='MaxTemperatureC', bins=10);

# %% [markdown]
# ## Gráfico de barras

# %% [markdown]
# En el caso de variables categóricas no necesito hacer "bins" puesto que barra se correspondrá con una categoría, por lo que usaremos gráficos de barras.

# %%
df2['Events'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Events'>

# %%
df2['Events'].value_counts().plot(x='Eventos',y='frecuencia',
                                           kind='bar', legend=True,
                                  title='Distribucion de los eventos');

# %% [markdown]
# # Otros gráficos interesantes

# %% [markdown]
# ## Gráfico de correlación entre las variables

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# La correlación sólo puede verse entre variables numéricas por lo que filtramos las variables que no lo son

# %%
df2_num = df2[df2.describe().columns]

# %%
plt.matshow(df2_num.corr())

# %%
corr = df2_num.corr()
corr
# Out:
#                          MaxTemperatureC  MeanTemperatureC  MinTemperatureC  \
# MaxTemperatureC                 1.000000          0.970986         0.856159
# MeanTemperatureC                0.970986          1.000000         0.951884
# MinTemperatureC                 0.856159          0.951884         1.000000
# MaxHumidity                    -0.718130         -0.694884        -0.609296
# MeanHumidity                   -0.805979         -0.742866        -0.601366
# MinHumidity                    -0.761731         -0.663328        -0.480051
# MaxSeaLevelPressurehPa         -0.081692         -0.191252        -0.320060
# MeanSeaLevelPressurehPa        -0.011039         -0.123687        -0.260055
# MinSeaLevelPressurehPa         -0.042501         -0.145117        -0.264250
# MaxWindSpeedKm/h                0.025233          0.114249         0.216601
# MeanWindSpeedKm/h              -0.073147          0.031270         0.160551
# Precipitationmm                -0.068204         -0.036426         0.002708
# WindDirDegrees                  0.000491         -0.027802        -0.063695
#
#                          MaxHumidity  MeanHumidity  MinHumidity  \
# MaxTemperatureC            -0.718130     -0.805979    -0.761731
# MeanTemperatureC           -0.694884     -0.742866    -0.663328
# MinTemperatureC            -0.609296     -0.601366    -0.480051
# MaxHumidity                 1.000000      0.906833     0.728406
# MeanHumidity                0.906833      1.000000     0.919671
# MinHumidity                 0.728406      0.919671     1.000000
# MaxSeaLevelPressurehPa      0.098447      0.057625    -0.041440
# MeanSeaLevelPressurehPa     0.048478      0.004853    -0.083535
# MinSeaLevelPressurehPa      0.081232      0.044863    -0.032136
# MaxWindSpeedKm/h           -0.147014     -0.138542    -0.080631
# MeanWindSpeedKm/h          -0.157711     -0.116631    -0.030020
# Precipitationmm             0.106559      0.114402     0.090659
# WindDirDegrees              0.036456      0.017772    -0.022011
#
#                          MaxSeaLevelPressurehPa  MeanSeaLevelPressurehPa  \
# MaxTemperatureC                       -0.081692                -0.011039
# MeanTemperatureC                      -0.191252                -0.123687
# MinTemperatureC                       -0.320060                -0.260055
# MaxHumidity                            0.098447                 0.048478
# MeanHumidity                           0.057625                 0.004853
# MinHumidity                           -0.041440                -0.083535
# MaxSeaLevelPressurehPa                 1.000000                 0.973027
# MeanSeaLevelPressurehPa                0.973027                 1.000000
# MinSeaLevelPressurehPa                 0.916735                 0.968574
# MaxWindSpeedKm/h                      -0.417619                -0.461154
# MeanWindSpeedKm/h                     -0.380324                -0.424301
# Precipitationmm                       -0.102311                -0.126434
# WindDirDegrees                         0.015054                 0.004340
#
#                          MinSeaLevelPressurehPa  MaxWindSpeedKm/h  \
# MaxTemperatureC                       -0.042501          0.025233
# MeanTemperatureC                      -0.145117          0.114249
# MinTemperatureC                       -0.264250          0.216601
# MaxHumidity                            0.081232         -0.147014
# MeanHumidity                           0.044863         -0.138542
# MinHumidity                           -0.032136         -0.080631
# MaxSeaLevelPressurehPa                 0.916735         -0.417619
# MeanSeaLevelPressurehPa                0.968574         -0.461154
# MinSeaLevelPressurehPa                 1.000000         -0.475765
# MaxWindSpeedKm/h                      -0.475765          1.000000
# MeanWindSpeedKm/h                     -0.434972          0.751420
# Precipitationmm                       -0.132689          0.095633
# WindDirDegrees                        -0.003460         -0.027492
#
#                          MeanWindSpeedKm/h  Precipitationmm  WindDirDegrees
# MaxTemperatureC                  -0.073147        -0.068204        0.000491
# MeanTemperatureC                  0.031270        -0.036426       -0.027802
# MinTemperatureC                   0.160551         0.002708       -0.063695
# MaxHumidity                      -0.157711         0.106559        0.036456
# MeanHumidity                     -0.116631         0.114402        0.017772
# MinHumidity                      -0.030020         0.090659       -0.022011
# MaxSeaLevelPressurehPa           -0.380324        -0.102311        0.015054
# MeanSeaLevelPressurehPa          -0.424301        -0.126434        0.004340
# MinSeaLevelPressurehPa           -0.434972        -0.132689       -0.003460
# MaxWindSpeedKm/h                  0.751420         0.095633       -0.027492
# MeanWindSpeedKm/h                 1.000000         0.066417       -0.020124
# Precipitationmm                   0.066417         1.000000       -0.031164
# WindDirDegrees                   -0.020124        -0.031164        1.000000

# %%
# 1.2 COLORES
# Hay que ejecutarlo todo a la vez.
f, ax = plt.subplots(figsize=(10, 8))
corr = df2_num.corr()
sns.heatmap(corr, annot = True, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax);

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
numeric_df = df2.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()

# Crear una máscara para enmascarar la diagonal principal y los valores por encima
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', mask=mask)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Diagrama de dispersión

# %% [markdown]
# Este gráfico no admite NAs.
# Dibuja gráficos de dispersión para cada par de variables en el conjunto de datos.
#
# Consume mucha capacidad de cómputo si usamos demasiadas variables ya que el número de gráficos crece al cuadrado.
#
# 7 variables -> 49 gráficos
#
# Conviene centrarse en aquellas columnas que han dado alta correlación en el gráfico anterior.

# %%
df2_num.dropna().columns
# Out:
# Index(['CET', 'MaxTemperatureC', 'MeanTemperatureC', 'MinTemperatureC',
#        'MaxHumidity', 'MeanHumidity', 'MinHumidity', 'MaxSeaLevelPressurehPa',
#        'MeanSeaLevelPressurehPa', 'MinSeaLevelPressurehPa', 'MaxWindSpeedKm/h',
#        'MeanWindSpeedKm/h', 'Precipitationmm', 'WindDirDegrees'],
#       dtype='object')

# %%
variables_correladas = ['MaxTemperatureC', 'MeanTemperatureC', 'MinTemperatureC',
                        'MaxHumidity', 'MeanHumidity', 'MinHumidity']

# %%
import seaborn as sns
datoscomp=df2_num.dropna()[variables_correladas]
sns.pairplot(datoscomp);
