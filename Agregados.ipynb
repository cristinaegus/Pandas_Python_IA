# %% [markdown]
# <a href="https://colab.research.google.com/github/cristinaegus/Pandas_Python_IA/blob/main/Agregados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Agregados. (Verticalización y Normalización)

# %%
import os
import pandas as pd

# %%
os.chdir(r"/content/sample_data")
SalePrice=pd.read_csv("SalePrice.csv")

# %%
SalePrice.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
SalePrice.shape
# Out:
# (1459, 80)

# %% [markdown]
# # Detección de columnas categóricas.

# %% [markdown]
# Puedo ver cuantas variables categóricas tengo.
#
# Podemos aplicar cualquier función columna por columna usando `apply`.
#
# En este caso deseamos que nos devuelva el número de valores únicos de cada columna x. Usando una función anónima

# %%
val_unicos = SalePrice.apply(lambda x: len(x.unique()))
val_unicos
# Out:
# Id               1459
# MSSubClass         16
# MSZoning            6
# LotFrontage       116
# LotArea          1106
#                  ...
# MiscVal            26
# MoSold             12
# YrSold              5
# SaleType           10
# SaleCondition       6
# Length: 80, dtype: int64

# %% [markdown]
# O usando una función con nombre.

# %%
def val_unicos(columna):
    return columna.nunique()

# %%
val_unicos = SalePrice.apply(val_unicos)
val_unicos
# Out:
# Id               1459
# MSSubClass         16
# MSZoning            5
# LotFrontage       115
# LotArea          1106
#                  ...
# MiscVal            26
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 80, dtype: int64

# %% [markdown]
# Aunque ya existe una función específica en pandas para esto

# %%
val_unicos = SalePrice.nunique()
val_unicos
# Out:
# Id               1459
# MSSubClass         16
# MSZoning            5
# LotFrontage       115
# LotArea          1106
#                  ...
# MiscVal            26
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 80, dtype: int64

# %% [markdown]
# Sin embargo, existe una diferencia. El primer método (unique) incluye `nan` como una de las categorías posibles en cambio nunique no.

# %% [markdown]
# Puesto que el resultado es una serie, puedo filtrar los valores. Si el número de valores únicos es inferior, digamos, a 10, considero que esa columna es categórica.

# %%
val_unicos[val_unicos < 10]
# Out:
# MSZoning         5
# Street           2
# Alley            2
# LotShape         4
# LandContour      4
# Utilities        1
# LotConfig        5
# LandSlope        3
# Condition1       9
# Condition2       5
# BldgType         5
# HouseStyle       7
# OverallCond      9
# RoofStyle        6
# RoofMatl         4
# MasVnrType       3
# ExterQual        4
# ExterCond        5
# Foundation       6
# BsmtQual         4
# BsmtCond         4
# BsmtExposure     4
# BsmtFinType1     6
# BsmtFinType2     6
# Heating          4
# HeatingQC        5
# CentralAir       2
# Electrical       4
# BsmtFullBath     4
# BsmtHalfBath     3
# FullBath         5
# HalfBath         3
# BedroomAbvGr     7
# KitchenAbvGr     3
# KitchenQual      4
# Functional       7
# Fireplaces       5
# FireplaceQu      5
# GarageType       6
# GarageFinish     3
# GarageCars       6
# GarageQual       4
# GarageCond       5
# PavedDrive       3
# PoolArea         7
# PoolQC           2
# Fence            4
# MiscFeature      3
# YrSold           5
# SaleType         9
# SaleCondition    6
# dtype: int64

# %% [markdown]
# Ahora puedo ver cómo están distribuidos esos valores únicos.

# %%
SalePrice["MSZoning"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='MSZoning'>

# %%
SalePrice["BldgType"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='BldgType'>

# %% [markdown]
# # Agregaciones

# %%
ZonaConteo = SalePrice.groupby('MSZoning').agg(len).reset_index()
ZonaConteo
# Out:
#   MSZoning    Id  MSSubClass  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  C (all)    15          15           15       15      15     15        15
# 1       FV    74          74           74       74      74     74        74
# 2       RH    10          10           10       10      10     10        10
# 3       RL  1114        1114         1114     1114    1114   1114      1114
# 4       RM   242         242          242      242     242    242       242
#
#    LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0           15         15  ...           15        15      15     15
# 1           74         74  ...           74        74      74     74
# 2           10         10  ...           10        10      10     10
# 3         1114       1114  ...         1114      1114    1114   1114
# 4          242        242  ...          242       242     242    242
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0           15       15      15      15        15             15
# 1           74       74      74      74        74             74
# 2           10       10      10      10        10             10
# 3         1114     1114    1114    1114      1114           1114
# 4          242      242     242     242       242            242
#
# [5 rows x 80 columns]

# %% [markdown]
# Tambien podemos realizar el sumatorio.
#
# Si incluimos todas las variables, las de tipo String darán resultados no deseados.
#
# Si en lugar de `sum` hubiéramos usado `mean`, el cálculo sería imposible.

# %%
ZonaSuma = SalePrice.groupby('MSZoning').agg("sum").reset_index()
ZonaSuma
# Out:
#   MSZoning       Id  MSSubClass  LotFrontage   LotArea  \
# 0  C (all)    34590         940        812.0    113005
# 1       FV   150988        6540       3693.0    478835
# 2       RH    19555        1050        509.0     77087
# 3       RL  2444600       55020      67327.0  11979696
# 4       RM   536188       20025      11836.0   1553319
#
#                                               Street  \
# 0  PaveGrvlPavePavePavePavePaveGrvlPavePavePavePa...
# 1  PavePavePavePavePavePavePavePavePavePavePavePa...
# 2           PavePavePavePavePavePavePavePavePavePave
# 3  PavePavePavePavePavePavePavePavePavePavePavePa...
# 4  PavePavePavePavePavePavePavePavePavePavePavePa...
#
#                                                Alley  \
# 0                                               Grvl
# 1  PavePavePavePavePavePavePavePavePavePavePavePa...
# 2                                           PavePave
# 3  PaveGrvlGrvlGrvlGrvlGrvlGrvlGrvlPaveGrvlGrvlGr...
# 4  GrvlGrvlGrvlGrvlGrvlGrvlGrvlGrvlGrvlGrvlGrvlGr...
#
#                                             LotShape  \
# 0      IR1RegRegRegRegRegRegRegRegRegRegRegRegRegReg
# 1  RegRegIR1RegRegRegRegRegIR1IR1IR1RegRegRegRegI...
# 2                     RegIR1RegRegRegRegIR1IR2IR2Reg
# 3  IR1IR1IR1IR1IR1IR1IR1RegRegRegRegIR1IR1RegIR1R...
# 4  RegRegRegRegRegRegRegRegRegRegRegRegRegRegRegR...
#
#                                          LandContour  \
# 0      LvlLvlLvlLvlLvlLvlLvlBnkLvlLvlLvlLvlLvlLvlBnk
# 1  LvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlL...
# 2                     LvlLvlLvlLvlLvlLvlLvlLvlLvlBnk
# 3  LvlLvlLvlHLSLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlH...
# 4  LvlLvlLvlLvlBnkLvlLvlLvlLvlLvlLvlLvlLvlLvlLvlL...
#
#                                            Utilities  ... ScreenPorch  \
# 0  AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...  ...           0
# 1  AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...  ...         744
# 2  AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...  ...         120
# 3  AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...  ...       21346
# 4  AllPubAllPubAllPubAllPubAllPubAllPubAllPubAllP...  ...        2687
#
#   PoolArea  PoolQC                                              Fence  \
# 0        0       0                                                  0
# 1        0       0                                              GdPrv
# 2        0       0                                              MnPrv
# 3     2545  ExExGd  MnPrvGdPrvMnPrvGdPrvGdWoGdPrvGdWoMnPrvGdPrvGdW...
# 4        0       0  MnPrvMnPrvMnPrvMnPrvMnPrvGdPrvGdPrvMnPrvMnPrvM...
#
#                                          MiscFeature MiscVal MoSold   YrSold  \
# 0                                                  0       0    106    30116
# 1                                                  0       0    463   148595
# 2                                               Shed     500     64    20085
# 3  Gar2ShedShedShedShedShedShedShedShedShedShedSh...   78067   6827  2236617
# 4                                   ShedShedShedGar2    6300   1435   485892
#
#                                             SaleType  \
# 0                  WDWDWDWDWDWDWDWDWDWDWDConLDWDWDWD
# 1  NewWDWDWDConLDWDWDWDWDNewWDWDWDWDWDNewWDWDWDWD...
# 2                              WDWDWDCODWDWDWDWDWDWD
# 3  WDWDWDWDWDWDWDWDWDWDWDNewNewWDWDWDWDWDWDWDWDWD...
# 4  CODWDCODWDWDWDWDWDWDWDWDWDWDWDWDWDWDWDWDWDWDWD...
#
#                                        SaleCondition
# 0  AbnormlAllocaNormalAbnormlNormalNormalNormalNo...
# 1  PartialNormalNormalNormalNormalNormalNormalNor...
# 2  NormalNormalNormalNormalNormalAbnormlNormalNor...
# 3  NormalNormalNormalNormalNormalNormalNormalNorm...
# 4  NormalNormalAbnormlNormalNormalNormalNormalNor...
#
# [5 rows x 80 columns]

# %% [markdown]
# Solo incluye variables numericas.

# %%
SalePrice_num = SalePrice.select_dtypes(["number", "bool"])
# Necesito recuperar la columna categórica con la que hago el agregado
SalePrice_num["MSZoning"] = SalePrice["MSZoning"]

# %%
ZonaSuma = SalePrice_num.groupby('MSZoning').agg("sum").reset_index()
ZonaSuma
# Out:
#   MSZoning       Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0  C (all)    34590         940        812.0    113005           59
# 1       FV   150988        6540       3693.0    478835          542
# 2       RH    19555        1050        509.0     77087           55
# 3       RL  2444600       55020      67327.0  11979696         6909
# 4       RM   536188       20025      11836.0   1553319         1295
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  GarageArea  \
# 0           80      28775         29444         0.0  ...      2062.0
# 1          370     148274        148302      8381.0  ...     42806.0
# 2           54      19640         19728        88.0  ...      4386.0
# 3         6137    2201954       2211230    124033.0  ...    555838.0
# 4         1449     469855        477657     12922.0  ...     82880.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0         154          666           1133         86            0         0
# 1        4976         8234             36        224          744         0
# 2         852          416            135          0          120         0
# 3      117792        53696          21840       1556        21346      2545
# 4       12049         7454          12092        752         2687         0
#
#    MiscVal  MoSold   YrSold
# 0        0     106    30116
# 1        0     463   148595
# 2      500      64    20085
# 3    78067    6827  2236617
# 4     6300    1435   485892
#
# [5 rows x 38 columns]

# %%
SalePrice_num.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'MSZoning'],
#       dtype='object')

# %% [markdown]
# Puedo asignar una función de agregación distinta a cada columna de datos.

# %%
dict_calculos = {'YearBuilt': 'mean',
                 'OverallQual': 'mean',
                 'LotArea': 'sum'}
ZonaSuma = SalePrice_num.groupby('MSZoning').agg(dict_calculos).reset_index()
ZonaSuma
# Out:
#   MSZoning    YearBuilt  OverallQual   LotArea
# 0  C (all)  1918.333333     3.933333    113005
# 1       FV  2003.702703     7.324324    478835
# 2       RH  1964.000000     5.500000     77087
# 3       RL  1976.619390     6.201975  11979696
# 4       RM  1941.549587     5.351240   1553319

# %% [markdown]
# Vamos a definir una función personalizada que en lugar de sumar los valores suma el módulo de los valores

# %%
serie = pd.Series([0, 1, -2, 3])
serie.abs().sum()
# Out:
# np.int64(6)

# %%
def suma_mod(serie):
    return serie.abs().sum()

# %%
ZonaSuma = SalePrice_num.groupby('MSZoning').agg(suma_mod).reset_index()
ZonaSuma
# Out:
#   MSZoning       Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0  C (all)    34590         940        812.0    113005           59
# 1       FV   150988        6540       3693.0    478835          542
# 2       RH    19555        1050        509.0     77087           55
# 3       RL  2444600       55020      67327.0  11979696         6909
# 4       RM   536188       20025      11836.0   1553319         1295
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  GarageArea  \
# 0           80      28775         29444         0.0  ...      2062.0
# 1          370     148274        148302      8381.0  ...     42806.0
# 2           54      19640         19728        88.0  ...      4386.0
# 3         6137    2201954       2211230    124033.0  ...    555838.0
# 4         1449     469855        477657     12922.0  ...     82880.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0         154          666           1133         86            0         0
# 1        4976         8234             36        224          744         0
# 2         852          416            135          0          120         0
# 3      117792        53696          21840       1556        21346      2545
# 4       12049         7454          12092        752         2687         0
#
#    MiscVal  MoSold   YrSold
# 0        0     106    30116
# 1        0     463   148595
# 2      500      64    20085
# 3    78067    6827  2236617
# 4     6300    1435   485892
#
# [5 rows x 38 columns]

# %%
ZonaSuma = SalePrice_num.groupby('MSZoning').agg(lambda x: x.abs().sum()).reset_index()
ZonaSuma
# Out:
#   MSZoning       Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0  C (all)    34590         940        812.0    113005           59
# 1       FV   150988        6540       3693.0    478835          542
# 2       RH    19555        1050        509.0     77087           55
# 3       RL  2444600       55020      67327.0  11979696         6909
# 4       RM   536188       20025      11836.0   1553319         1295
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  GarageArea  \
# 0           80      28775         29444         0.0  ...      2062.0
# 1          370     148274        148302      8381.0  ...     42806.0
# 2           54      19640         19728        88.0  ...      4386.0
# 3         6137    2201954       2211230    124033.0  ...    555838.0
# 4         1449     469855        477657     12922.0  ...     82880.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0         154          666           1133         86            0         0
# 1        4976         8234             36        224          744         0
# 2         852          416            135          0          120         0
# 3      117792        53696          21840       1556        21346      2545
# 4       12049         7454          12092        752         2687         0
#
#    MiscVal  MoSold   YrSold
# 0        0     106    30116
# 1        0     463   148595
# 2      500      64    20085
# 3    78067    6827  2236617
# 4     6300    1435   485892
#
# [5 rows x 38 columns]

# %%
dict_calculos = {'YearBuilt': 'mean',
                 'OverallQual': suma_mod,
                 'LotArea': 'sum'}
ZonaSuma = SalePrice_num.groupby('MSZoning').agg(dict_calculos).reset_index()
ZonaSuma
# Out:
#   MSZoning    YearBuilt  OverallQual   LotArea
# 0  C (all)  1918.333333           59    113005
# 1       FV  2003.702703          542    478835
# 2       RH  1964.000000           55     77087
# 3       RL  1976.619390         6909  11979696
# 4       RM  1941.549587         1295   1553319

# %% [markdown]
# ## Agregaciones con varias variables

# %% [markdown]
# Tambien se pueden realizar agregaciones por mas de una variable.
#
# Puedo crear un DataFrame con las combinaciones de ambas variables categóricas existentes en los datos:

# %%
SP1 = SalePrice.loc[:, ['MSZoning',"BldgType"]].drop_duplicates()
SP1
# Out:
#      MSZoning BldgType
# 0          RH     1Fam
# 1          RL     1Fam
# 4          RL   TwnhsE
# 10         RH   TwnhsE
# 11         RM    Twnhs
# 13         RL    Twnhs
# 28         FV     1Fam
# 35         FV   TwnhsE
# 38         FV    Twnhs
# 53         RL   Duplex
# 65         RL   2fmCon
# 70         RM     1Fam
# 79         RM   2fmCon
# 98    C (all)     1Fam
# 99         RH   2fmCon
# 124        RM   TwnhsE
# 133        RH   Duplex
# 346        RM   Duplex
# 455       NaN     1Fam
# 1119  C (all)   2fmCon

# %%
SalePrice[["MSZoning", "BldgType"]].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='MSZoning,BldgType'>

# %%
zona_tipo = SalePrice.groupby(['MSZoning',"BldgType"]).agg(len).reset_index()
zona_tipo
# Out:
#    MSZoning BldgType   Id  MSSubClass  LotFrontage  LotArea  Street  Alley  \
# 0   C (all)     1Fam   13          13           13       13      13     13
# 1   C (all)   2fmCon    2           2            2        2       2      2
# 2        FV     1Fam   39          39           39       39      39     39
# 3        FV    Twnhs   10          10           10       10      10     10
# 4        FV   TwnhsE   25          25           25       25      25     25
# 5        RH     1Fam    3           3            3        3       3      3
# 6        RH   2fmCon    2           2            2        2       2      2
# 7        RH   Duplex    1           1            1        1       1      1
# 8        RH   TwnhsE    4           4            4        4       4      4
# 9        RL     1Fam  984         984          984      984     984    984
# 10       RL   2fmCon   14          14           14       14      14     14
# 11       RL   Duplex   49          49           49       49      49     49
# 12       RL    Twnhs   14          14           14       14      14     14
# 13       RL   TwnhsE   53          53           53       53      53     53
# 14       RM     1Fam  162         162          162      162     162    162
# 15       RM   2fmCon   13          13           13       13      13     13
# 16       RM   Duplex    7           7            7        7       7      7
# 17       RM    Twnhs   29          29           29       29      29     29
# 18       RM   TwnhsE   31          31           31       31      31     31
#
#     LotShape  LandContour  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0         13           13  ...           13        13      13     13
# 1          2            2  ...            2         2       2      2
# 2         39           39  ...           39        39      39     39
# 3         10           10  ...           10        10      10     10
# 4         25           25  ...           25        25      25     25
# 5          3            3  ...            3         3       3      3
# 6          2            2  ...            2         2       2      2
# 7          1            1  ...            1         1       1      1
# 8          4            4  ...            4         4       4      4
# 9        984          984  ...          984       984     984    984
# 10        14           14  ...           14        14      14     14
# 11        49           49  ...           49        49      49     49
# 12        14           14  ...           14        14      14     14
# 13        53           53  ...           53        53      53     53
# 14       162          162  ...          162       162     162    162
# 15        13           13  ...           13        13      13     13
# 16         7            7  ...            7         7       7      7
# 17        29           29  ...           29        29      29     29
# 18        31           31  ...           31        31      31     31
#
#     MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            13       13      13      13        13             13
# 1             2        2       2       2         2              2
# 2            39       39      39      39        39             39
# 3            10       10      10      10        10             10
# 4            25       25      25      25        25             25
# 5             3        3       3       3         3              3
# 6             2        2       2       2         2              2
# 7             1        1       1       1         1              1
# 8             4        4       4       4         4              4
# 9           984      984     984     984       984            984
# 10           14       14      14      14        14             14
# 11           49       49      49      49        49             49
# 12           14       14      14      14        14             14
# 13           53       53      53      53        53             53
# 14          162      162     162     162       162            162
# 15           13       13      13      13        13             13
# 16            7        7       7       7         7              7
# 17           29       29      29      29        29             29
# 18           31       31      31      31        31             31
#
# [19 rows x 80 columns]

# %% [markdown]
# Y sumar

# %%
SalePrice_num["BldgType"] = SalePrice["BldgType"]

# %%
zona_tipo_suma = SalePrice_num.groupby(['MSZoning',"BldgType"]).agg("sum").reset_index()
zona_tipo_suma
# Out:
#    MSZoning BldgType       Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0   C (all)     1Fam    29117         560        687.0     95755           49
# 1   C (all)   2fmCon     5473         380        125.0     17250           10
# 2        FV     1Fam    79975        1500       2811.0    359197          290
# 3        FV    Twnhs    20329        1600        248.0     24639           68
# 4        FV   TwnhsE    50684        3440        634.0     94999          184
# 5        RH     1Fam     4850         100        220.0     27722           15
# 6        RH   2fmCon     4435         380        118.0     12478           11
# 7        RH   Duplex     1594          90         60.0      7200            4
# 8        RH   TwnhsE     8676         480        111.0     29687           25
# 9        RL     1Fam  2165928       39620      60840.0  11000097         6099
# 10       RL   2fmCon    32678        2660       1112.0    174779           70
# 11       RL   Duplex   105366        4410       2626.0    454953          254
# 12       RL    Twnhs    29210        1870        364.0     40145           93
# 13       RL   TwnhsE   111418        6460       2385.0    309722          393
# 14       RM     1Fam   354698        8075       9046.0   1228047          844
# 15       RM   2fmCon    27714        2340        791.0    110301           64
# 16       RM   Duplex    16456         630        466.0     54296           42
# 17       RM    Twnhs    65535        4680        613.0     51320          152
# 18       RM   TwnhsE    71785        4300        920.0    109355          193
#
#     OverallCond  YearBuilt  YearRemodAdd  ...  GarageArea  WoodDeckSF  \
# 0            68      24929         25487  ...      2062.0         154
# 1            12       3846          3957  ...         0.0           0
# 2           195      78181         78197  ...     24771.0        3504
# 3            50      20013         20017  ...      4886.0         358
# 4           125      50080         50088  ...     13149.0        1114
# 5            15       5819          5861  ...      1409.0         261
# 6            13       3855          3900  ...       890.0          56
# 7             6       1967          1967  ...         0.0           0
# 8            20       7999          8000  ...      2087.0         535
# 9          5467    1944520       1953399  ...    495554.0      107241
# 10           73      27326         27562  ...      5260.0        1501
# 11          249      96459         96602  ...     21410.0        2347
# 12           77      27813         27817  ...      6603.0        1015
# 13          271     105836        105850  ...     27011.0        5688
# 14         1016     312196        319188  ...     55071.0        6281
# 15           73      24955         25573  ...      3897.0         298
# 16           34      13720         13820  ...      3141.0         160
# 17          164      57247         57317  ...      7523.0        2853
# 18          162      61737         61759  ...     13248.0        2457
#
#     OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0           666           1000         86            0         0        0
# 1             0            133          0            0         0        0
# 2          4991             36        224          650         0        0
# 3           745              0          0            0         0        0
# 4          2498              0          0           94         0        0
# 5             0            135          0          120         0        0
# 6           144              0          0            0         0        0
# 7             0              0          0            0         0      500
# 8           272              0          0            0         0        0
# 9         49142          20411       1556        19993      2545    75495
# 10          570            717          0          144         0      460
# 11         1065            418          0            0         0     2112
# 12          511              0          0          200         0        0
# 13         2408            294          0         1009         0        0
# 14         5311          10065        326         1808         0     5300
# 15          384           1482          0            0         0     1000
# 16          329            425          0            0         0        0
# 17          427             56        120          108         0        0
# 18         1003             64        306          771         0        0
#
#     MoSold   YrSold
# 0       90    26103
# 1       16     4013
# 2      261    78311
# 3       73    20081
# 4      129    50203
# 5       17     6029
# 6       13     4016
# 7        2     2010
# 8       32     8030
# 9     5994  1975601
# 10      75    28103
# 11     327    98394
# 12      84    28109
# 13     347   106410
# 14     938   325276
# 15      66    26104
# 16      64    14052
# 17     184    58222
# 18     183    62238
#
# [19 rows x 39 columns]

# %% [markdown]
# # Verticalización

# %% [markdown]
# Verticalizar un DataFrame en pandas generalmente se refiere a transformar datos de un formato de tabla a lo ancho (horizontal) a un formato a lo largo (vertical).
#
# Se suele realizar convirtiendo varias columnas en valores categóricos en una nueva columna. Los datos que se guardaran en esas columnas eliminadas se incorporarán de arriba a abajo en la segunda nueva columna creada.
#
# Esto se puede lograr utilizando las funciones `melt` y `stack` de pandas.

# %% [markdown]
# ## `melt`

# %%
import pandas as pd

# Crear DataFrame de ejemplo
datos = pd.DataFrame({
    'DNI': ["14543234L", "23445853Z", "17754679L"],
    'Matemáticas': [9.0, 8.0, 8.5],
    'Física': [7.0, 8.5, 9.1],
    'Química': [6.0, 5.5, 7.3]
})

datos
# Out:
#          DNI  Matemáticas  Física  Química
# 0  14543234L          9.0     7.0      6.0
# 1  23445853Z          8.0     8.5      5.5
# 2  17754679L          8.5     9.1      7.3

# %% [markdown]
# Ahora la columna DNI ya no es de valores únicos. Sí lo será la combinación DNI - Asignatura
#
# Puesto que se crean dos columnas, debemos dar dos nombres nuevos de columna, una para las variables que van a desaparecer y otra para los valores que vamos a concatenar verticalmente. (Si no las llamará `variable` y `value` automáticamente)

# %%
datos_vert = pd.melt(datos, id_vars=['DNI'], var_name='Asignatura', value_name='Notas')
datos_vert
# Out:
#          DNI   Asignatura  Notas
# 0  14543234L  Matemáticas    9.0
# 1  23445853Z  Matemáticas    8.0
# 2  17754679L  Matemáticas    8.5
# 3  14543234L       Física    7.0
# 4  23445853Z       Física    8.5
# 5  17754679L       Física    9.1
# 6  14543234L      Química    6.0
# 7  23445853Z      Química    5.5
# 8  17754679L      Química    7.3

# %%
datos_vert.groupby("Asignatura").agg({"Notas": "mean"})
# Out:
#                 Notas
# Asignatura
# Física       8.200000
# Matemáticas  8.500000
# Química      6.266667

# %%
datos_vert.groupby("DNI").agg({"Notas": "mean"})
# Out:
#               Notas
# DNI
# 14543234L  7.333333
# 17754679L  8.300000
# 23445853Z  7.333333

# %% [markdown]
# ## `stack`

# %% [markdown]
# Si no tenemos una columna de identificadores y queremos usar el índice podemos usar `stack`.

# %%
import pandas as pd

# Crear DataFrame de ejemplo
datos = pd.DataFrame({
    'Matemáticas': [9.0, 8.0, 8.5],
    'Física': [7.0, 8.5, 9.1],
    'Química': [6.0, 5.5, 7.3]
})

datos
# Out:
#    Matemáticas  Física  Química
# 0          9.0     7.0      6.0
# 1          8.0     8.5      5.5
# 2          8.5     9.1      7.3

# %% [markdown]
# Obtenemos un objeto de tipo `Series` con doble índice. Las columnas se convertirán en el índice interno.

# %%
# Verticalizar el DataFrame usando stack
datos_stacked = datos.stack()
print(type(datos_stacked))
datos_stacked
# Out:
# <class 'pandas.core.series.Series'>
# 0  Matemáticas    9.0
#    Física         7.0
#    Química        6.0
# 1  Matemáticas    8.0
#    Física         8.5
#    Química        5.5
# 2  Matemáticas    8.5
#    Física         9.1
#    Química        7.3
# dtype: float64

# %% [markdown]
# Con `reset_index` el índice doble se promocionara a columnas para que sean los nuevos indicadores únicos de la tabla.

# %%
# Verticalizar el DataFrame usando stack
datos_stacked = datos.stack().reset_index()
datos_stacked.columns = ['id', 'Asignatura', 'Nota']
datos_stacked
# Out:
#    id   Asignatura  Nota
# 0   0  Matemáticas   9.0
# 1   0       Física   7.0
# 2   0      Química   6.0
# 3   1  Matemáticas   8.0
# 4   1       Física   8.5
# 5   1      Química   5.5
# 6   2  Matemáticas   8.5
# 7   2       Física   9.1
# 8   2      Química   7.3

# %% [markdown]
# ## `pivot`
#
# Realiza el paso contrario de `melt` y `stack`

# %%
Normal = datos_stacked.pivot(index='id', columns='Asignatura', values='Nota')
# Normal = datos_stacked.pivot(index='id', columns='Asignatura')['Nota']
Normal
# Out:
# Asignatura  Física  Matemáticas  Química
# id
# 0              7.0          9.0      6.0
# 1              8.5          8.0      5.5
# 2              9.1          8.5      7.3

# %%
Normal.columns
# Out:
# Index(['Física', 'Matemáticas', 'Química'], dtype='object', name='Asignatura')

# %%
print(Normal.columns, Normal.index)

Normal.columns.name = None
Normal.index.name = None

Normal
# Out:
# Index(['Física', 'Matemáticas', 'Química'], dtype='object', name='Asignatura') Index([0, 1, 2], dtype='int64', name='id')
#    Física  Matemáticas  Química
# 0     7.0          9.0      6.0
# 1     8.5          8.0      5.5
# 2     9.1          8.5      7.3

# %%
Normal["Física"]
# Out:
# 0    7.0
# 1    8.5
# 2    9.1
# Name: Física, dtype: float64

# %%
Normal.iloc[2,:]
# Out:
# Física         9.1
# Matemáticas    8.5
# Química        7.3
# Name: 2, dtype: float64

# %% [markdown]
# ### Ejemplo de pivotado con los datos de SalePrice

# %%
zona_tipo_suma
# Out:
#    MSZoning BldgType       Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0   C (all)     1Fam    29117         560        687.0     95755           49
# 1   C (all)   2fmCon     5473         380        125.0     17250           10
# 2        FV     1Fam    79975        1500       2811.0    359197          290
# 3        FV    Twnhs    20329        1600        248.0     24639           68
# 4        FV   TwnhsE    50684        3440        634.0     94999          184
# 5        RH     1Fam     4850         100        220.0     27722           15
# 6        RH   2fmCon     4435         380        118.0     12478           11
# 7        RH   Duplex     1594          90         60.0      7200            4
# 8        RH   TwnhsE     8676         480        111.0     29687           25
# 9        RL     1Fam  2165928       39620      60840.0  11000097         6099
# 10       RL   2fmCon    32678        2660       1112.0    174779           70
# 11       RL   Duplex   105366        4410       2626.0    454953          254
# 12       RL    Twnhs    29210        1870        364.0     40145           93
# 13       RL   TwnhsE   111418        6460       2385.0    309722          393
# 14       RM     1Fam   354698        8075       9046.0   1228047          844
# 15       RM   2fmCon    27714        2340        791.0    110301           64
# 16       RM   Duplex    16456         630        466.0     54296           42
# 17       RM    Twnhs    65535        4680        613.0     51320          152
# 18       RM   TwnhsE    71785        4300        920.0    109355          193
#
#     OverallCond  YearBuilt  YearRemodAdd  ...  GarageArea  WoodDeckSF  \
# 0            68      24929         25487  ...      2062.0         154
# 1            12       3846          3957  ...         0.0           0
# 2           195      78181         78197  ...     24771.0        3504
# 3            50      20013         20017  ...      4886.0         358
# 4           125      50080         50088  ...     13149.0        1114
# 5            15       5819          5861  ...      1409.0         261
# 6            13       3855          3900  ...       890.0          56
# 7             6       1967          1967  ...         0.0           0
# 8            20       7999          8000  ...      2087.0         535
# 9          5467    1944520       1953399  ...    495554.0      107241
# 10           73      27326         27562  ...      5260.0        1501
# 11          249      96459         96602  ...     21410.0        2347
# 12           77      27813         27817  ...      6603.0        1015
# 13          271     105836        105850  ...     27011.0        5688
# 14         1016     312196        319188  ...     55071.0        6281
# 15           73      24955         25573  ...      3897.0         298
# 16           34      13720         13820  ...      3141.0         160
# 17          164      57247         57317  ...      7523.0        2853
# 18          162      61737         61759  ...     13248.0        2457
#
#     OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0           666           1000         86            0         0        0
# 1             0            133          0            0         0        0
# 2          4991             36        224          650         0        0
# 3           745              0          0            0         0        0
# 4          2498              0          0           94         0        0
# 5             0            135          0          120         0        0
# 6           144              0          0            0         0        0
# 7             0              0          0            0         0      500
# 8           272              0          0            0         0        0
# 9         49142          20411       1556        19993      2545    75495
# 10          570            717          0          144         0      460
# 11         1065            418          0            0         0     2112
# 12          511              0          0          200         0        0
# 13         2408            294          0         1009         0        0
# 14         5311          10065        326         1808         0     5300
# 15          384           1482          0            0         0     1000
# 16          329            425          0            0         0        0
# 17          427             56        120          108         0        0
# 18         1003             64        306          771         0        0
#
#     MoSold   YrSold
# 0       90    26103
# 1       16     4013
# 2      261    78311
# 3       73    20081
# 4      129    50203
# 5       17     6029
# 6       13     4016
# 7        2     2010
# 8       32     8030
# 9     5994  1975601
# 10      75    28103
# 11     327    98394
# 12      84    28109
# 13     347   106410
# 14     938   325276
# 15      66    26104
# 16      64    14052
# 17     184    58222
# 18     183    62238
#
# [19 rows x 39 columns]

# %%
Normal2 = zona_tipo_suma.pivot(index='MSZoning', columns='BldgType', values='LotArea')
Normal2
# Out:
# BldgType        1Fam    2fmCon    Duplex    Twnhs    TwnhsE
# MSZoning
# C (all)      95755.0   17250.0       NaN      NaN       NaN
# FV          359197.0       NaN       NaN  24639.0   94999.0
# RH           27722.0   12478.0    7200.0      NaN   29687.0
# RL        11000097.0  174779.0  454953.0  40145.0  309722.0
# RM         1228047.0  110301.0   54296.0  51320.0  109355.0

# %% [markdown]
# # Verticalización por varias variables

# %%
# Crear DataFrame de ejemplo
data = {
    'tienda': ['Tienda A', 'Tienda B', 'Tienda C'],
    'producto': ['Producto 1', 'Producto 2', 'Producto 3'],
    'ventas_ene': [150, 200, 250],
    'ventas_feb': [160, 210, 260],
    'ventas_mar': [170, 220, 270]
}
df = pd.DataFrame(data)
df
# Out:
#      tienda    producto  ventas_ene  ventas_feb  ventas_mar
# 0  Tienda A  Producto 1         150         160         170
# 1  Tienda B  Producto 2         200         210         220
# 2  Tienda C  Producto 3         250         260         270

# %% [markdown]
# ## `melt`

# %%
df_vert = pd.melt(df, id_vars=['tienda', 'producto'], var_name='mes', value_name='ventas')
df_vert
# Out:
#      tienda    producto         mes  ventas
# 0  Tienda A  Producto 1  ventas_ene     150
# 1  Tienda B  Producto 2  ventas_ene     200
# 2  Tienda C  Producto 3  ventas_ene     250
# 3  Tienda A  Producto 1  ventas_feb     160
# 4  Tienda B  Producto 2  ventas_feb     210
# 5  Tienda C  Producto 3  ventas_feb     260
# 6  Tienda A  Producto 1  ventas_mar     170
# 7  Tienda B  Producto 2  ventas_mar     220
# 8  Tienda C  Producto 3  ventas_mar     270

# %%
df_vert["mes"] = df_vert["mes"].str.replace("ventas_", "")
df_vert
# Out:
#      tienda    producto  mes  ventas
# 0  Tienda A  Producto 1  ene     150
# 1  Tienda B  Producto 2  ene     200
# 2  Tienda C  Producto 3  ene     250
# 3  Tienda A  Producto 1  feb     160
# 4  Tienda B  Producto 2  feb     210
# 5  Tienda C  Producto 3  feb     260
# 6  Tienda A  Producto 1  mar     170
# 7  Tienda B  Producto 2  mar     220
# 8  Tienda C  Producto 3  mar     270

# %% [markdown]
# ## `pivot`

# %%
# Convertir el DataFrame de formato largo a formato ancho
df_wide = df_vert.pivot(index=['tienda', 'producto'], columns='mes', values='ventas').reset_index()
df_wide.columns.name = None  # Quitar el nombre de las columnas

df_wide
# Out:
#      tienda    producto  ene  feb  mar
# 0  Tienda A  Producto 1  150  160  170
# 1  Tienda B  Producto 2  200  210  220
# 2  Tienda C  Producto 3  250  260  270

# %%
SalePrice.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # Ejercicio con SalePrice

# %% [markdown]
# Construye un Dataframe agregando los datos de SalePrice utilizando dos variables categóricas.
#
# (Por ejemplo LotShape y LandContour)

# %%
SP = SalePrice[["LotShape", "LandContour", "YearRemodAdd", "YearBuilt", "LotArea", "OpenPorchSF"]]

# %%
SP.head()
# Out:
#   LotShape LandContour  YearRemodAdd  YearBuilt  LotArea  OpenPorchSF
# 0      Reg         Lvl          1961       1961    11622            0
# 1      IR1         Lvl          1958       1958    14267           36
# 2      IR1         Lvl          1998       1997    13830           34
# 3      IR1         Lvl          1998       1998     9978           36
# 4      IR1         HLS          1992       1992     5005           82

# %% [markdown]
# En el agregado deben aparecer la media del año de remodelación `YearRemodAdd` y el año de construcción `YearBuilt` y la suma del Área del lote `LotArea` y el área del porche abierto `OpenPorchSF`.
#
# (Intenta que el año de construcción medio aparezca como un número entero con una función personalizada)

# %%
SP.groupby(["LotShape", "LandContour"]).a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A continuación, viendo el agregado, podemos considerar que `LotShape` podría ser la columna categórica que se obtiene al verticalizar una tabla y que `LotArea` son los values de la tabla original.
#
# Deshaz esa hipotética verticalización con `pivot`
#
# Debe quedar algo así:
#
# ![image.png](data:image/png;base64,...)
